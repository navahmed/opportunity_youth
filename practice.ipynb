# %%
import pandas as pd

# %%
# !ls
# Out:
# KC_cities.csv   data            practice.ipynb  references      setup.sh
# LICENSE         environment.yml puma_names.csv  reports         src
# README.md       log             puma_was.csv    sch_emp.csv     wa_geo.csv
# Untitled.ipynb  notebooks       pums.csv        school.csv      was_rm.csv

# %%
wa_geo_walk = pd.read_csv('wa_geo_walk.csv')
# Out:
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (31,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
wa_geo_walk.head()
# Out:
#         tabblk2010  st stusps  \
# 0  530699501001175  53     WA
# 1  530699501001164  53     WA
# 2  530699501001173  53     WA
# 3  530699501001172  53     WA
# 4  530699501001179  53     WA
#
#                                               stname    cty  \
# 0  Washington                                    ...  53069
# 1  Washington                                    ...  53069
# 2  Washington                                    ...  53069
# 3  Washington                                    ...  53069
# 4  Washington                                    ...  53069
#
#                                              ctyname         trct  \
# 0  Wahkiakum County, WA                          ...  53069950100
# 1  Wahkiakum County, WA                          ...  53069950100
# 2  Wahkiakum County, WA                          ...  53069950100
# 3  Wahkiakum County, WA                          ...  53069950100
# 4  Wahkiakum County, WA                          ...  53069950100
#
# ...

# %%
pums_2017 = pd.read_csv("pums_2017.csv")

# %%
pums_20172 = pums_2017[pums_2017['puma'] == 11614]

# %%
pums_20172.head()
# Out:
#     rt       serialno  division  sporder   puma  region  st   adjinc  pwgtp  \
# 267  P  2014000216715         9        1  11614       4  53  1045195     22
# 268  P  2014000216715         9        2  11614       4  53  1045195     21
# 629  P  2014000224281         9        1  11614       4  53  1045195     17
# 630  P  2014000224281         9        2  11614       4  53  1045195     11
# 631  P  2014000224281         9        3  11614       4  53  1045195     13
#
#      agep  ...  pwgtp71  pwgtp72  pwgtp73  pwgtp74  pwgtp75  pwgtp76  pwgtp77  \
# 267    63  ...       24        6        6       21       22        7       38
# 268    63  ...       22        7        6       20       21        7       37
# 629    46  ...       20       18       15       15        5        5       19
# 630    49  ...       10       10        8       15        4        3       16
# 631    18  ...       12       11       17       11        4        4       13
#
#      pwgtp78  pwgtp79  pwgtp80
# ...

# %%
puma_file = pd.read_csv('/Users/naweedahmed/Desktop/Flatiron_Feb/project_one_feb/opportunity_youth/data/processed/puma_2010_names.csv')

# %%
puma_file.head()
# Out:
#    State_FIPS State_Name  CPUMA0010  PUMA   GEOID    GISJOIN  \
# 0           1    Alabama          1   100  100100  G01000100
# 1           1    Alabama          1   800  100800  G01000800
# 2           1    Alabama          1  1400  101400  G01001400
# 3           1    Alabama          1  1500  101500  G01001500
# 4           1    Alabama          1  1600  101600  G01001600
#
#                                            PUMA_Name
# 0  Lauderdale, Colbert, Franklin & Marion (Northe...
# 1                        St. Clair & Blount Counties
# 2  Walker, Marion (South & West), Fayette & Lamar...
# 3  Tuscaloosa (Outer) & Pickens Counties--Northpo...
# 4          Tuscaloosa & Northport (Southeast) Cities

# %%
geo_file = pd.read_csv('/Users/naweedahmed/Desktop/Flatiron_Feb/project_one_feb/opportunity_youth/data/geo_walk.csv')
# Out:
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (31,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
geo_file.head()
# Out:
#         tabblk2010  st stusps  \
# 0  530699501001175  53     WA
# 1  530699501001164  53     WA
# 2  530699501001173  53     WA
# 3  530699501001172  53     WA
# 4  530699501001179  53     WA
#
#                                               stname    cty  \
# 0  Washington                                    ...  53069
# 1  Washington                                    ...  53069
# 2  Washington                                    ...  53069
# 3  Washington                                    ...  53069
# 4  Washington                                    ...  53069
#
#                                              ctyname         trct  \
# 0  Wahkiakum County, WA                          ...  53069950100
# 1  Wahkiakum County, WA                          ...  53069950100
# 2  Wahkiakum County, WA                          ...  53069950100
# 3  Wahkiakum County, WA                          ...  53069950100
# 4  Wahkiakum County, WA                          ...  53069950100
#
# ...
